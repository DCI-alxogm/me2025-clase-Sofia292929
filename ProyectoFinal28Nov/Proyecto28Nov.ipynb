# %%
# !sudo apt-get install gcc
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# gcc is already the newest version (4:11.2.0-1ubuntu1).
# 0 upgraded, 0 newly installed, 0 to remove and 41 not upgraded.

# %%
# !gcc Euler.c -o euler -lm

# %%
# !./euler
# Out:
# === Metodo de Euler ===
# Ingresa x0: 0
# Ingresa y0: 1
# Ingresa tamano de paso h: 0.1
# Ingresa numero de iteraciones: 2
#
# Iter	 x		 y
# --------------------------------------
# 0	 0.000000	 1.000000
# 1	 0.100000	 1.100000
# 2	 0.200000	 1.220000

# %%
# !gcc rk2.c -o rk2 -lm

# %%
# !./rk2
# Out:
# === Metodo Runge Kutta de 2do Orden ===
# Ingresa x0: 0
# Ingresa y0: 1
# Ingresa tamano de paso h: 0.1
# Ingresa numero de iteraciones: 2
#
# Iter	 x		 y
# --------------------------------------
# 0	 0.000000	 1.000000
# 1	 0.100000	 1.110000
# 2	 0.200000	 1.242050

# %%
# !gcc rk4.c -o rk4 -lm

# %%
# !./rk4
# Out:
# === Metodo Runge Kutta de 4to Orden ===
# Ingresa x0: 0
# Ingresa y0: 1
# Ingresa tamano de paso h: 0.1
# Ingresa numero de iteraciones: 2
#
# Iter	 x		 y
# --------------------------------------
# 0	 0.000000	 1.000000
# 1	 0.100000	 1.110342
# 2	 0.200000	 1.242805

# %% [markdown]
# Este es el ejemplo **Sistema masa–resorte sin fricción (oscilador armónic**

# %%
# !gcc SistemaResorte.c -o SistemaResorte -lm

# %%
# !./SistemaResorte
# Out:
# Sistema de EDO: masa-resorte sin friccion
# dx/dt = v,  dv/dt = -k*x
#
# i   t      x(t)        v(t)
# -------------------------------------
# 0  0.00   1.000000   0.000000
# 1  0.10   1.000000   -0.100000
# 2  0.20   0.990000   -0.200000
# 3  0.30   0.970000   -0.299000
# 4  0.40   0.940100   -0.396000
# 5  0.50   0.900500   -0.490010
# 6  0.60   0.851499   -0.580060
# 7  0.70   0.793493   -0.665210
# 8  0.80   0.726972   -0.744559
# 9  0.90   0.652516   -0.817256
# 10  1.00   0.570790   -0.882508
