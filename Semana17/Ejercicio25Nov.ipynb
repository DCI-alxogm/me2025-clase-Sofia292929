# %%
# !gcc integradores.c -o integradores -lm

# %%
# !./integradores
# Out:
# Integracion numérica - 2 iteraciones (h = 0.10 s)
# Ecuacion: dv/dt = g - (C/m)*(v + a*(v/vmax)^b)
# Parametros: C=12.50, m=68.10, a=8.30, b=2.20, vmax=46.00, g=9.81
#
# -------------------------------------------------------------
# i   t(s)    Euler_v (m/s)    RK2_v (m/s)    RK4_v (m/s)
# -------------------------------------------------------------
# 0   0.00     0.0000000000      0.0000000000   0.0000000000
#
# ================== Iteracion 0: t = 0.00 -> 0.10 s ==================
#
# [ Euler explícito ]
#  v_n = 0.0000000000
#  f(v_n) = f(0.0000000000) = 9.8100000000
#  v_{n+1} = v_n + h * f(v_n) = 0.0000000000 + 0.10 * 9.8100000000 = 0.9810000000
#
# [ RK2 (midpoint) ]
#  v_n = 0.0000000000
#  k1 = f(v_n) = f(0.0000000000) = 9.8100000000
#  v_half = v_n + (h/2)*k1 = 0.4905000000
#  k2 = f(v_half) = f(0.4905000000) = 9.7198971082
#  v_{n+1} = v_n + h * k2 = 0.9719897108
#
# [ RK4 ]
#  v_n = 0.0000000000
#  k1 = f(v_n) = f(0.0000000000) = 9.8100000000
# ...
