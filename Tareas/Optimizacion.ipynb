# %%
# !gcc -o optimizar_isotermas optimizacion_isotermas_standalone.c -lm

# %%
# !./optimizar_isotermas
# Out:
# ╔════════════════════════════════════════════════════════════╗
# ║     OPTIMIZACIÓN DE ISOTERMAS DE ADSORCIÓN DE CAFÉ        ║
# ║          Minimización de Chi-cuadrado en C                 ║
# ║
# ╚════════════════════════════════════════════════════════════╝
#
# Leyendo datos desde: Experimental water adsorption isotherms.csv
#
# Temperatura 25°C: 52 puntos leídos
# Temperatura 35°C: 51 puntos leídos
# Temperatura 45°C: 50 puntos leídos
#
# ✓ Total de datos combinados: 153 puntos
#
# ════════════════════════════════════════════════════════════
# Optimizando modelo PELEG con método Simplex...
# Chi² inicial: 207.155744
# Convergencia alcanzada en iteración 148
# Chi² final: 83.393134
# RMSE: 0.738277
#
# ════════════════════════════════════════════════════════════
# Optimizando modelo DLP con método Simplex...
# Chi² inicial: 92.025392
# Convergencia alcanzada en iteración 169
# Chi² final: 84.749563
# RMSE: 0.744257
#
# ...
